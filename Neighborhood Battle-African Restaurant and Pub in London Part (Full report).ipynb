# %% [markdown]
# ### Neighborhood Battle-African Restaurant and Pub in London Part

# %% [markdown]
# ### Introduction
#
#
# There is are small amounts of unpopular or non-African top brand restaurants, pubs, café etc. despite the huge number of African and Caribbean population in London. This project will explore five boroughs with the highest African population in London using clustering and segmentation method and select a preferable cluster to establish an African brand restaurants, cafés, or pubs.
#
# This project explores boroughs with the highest African population in London it's explores and segments these boroughs. An in-depth look into these boroughs with the higher number African populations and where to establish top African restaurants, coffee shops/cafés and pubs.
# Data
#
#
# This project explore boroughs with high African population in London it's explore and segments these boroughs. A detail exploration into boroughs with the highest African populations and to establish top African resurants, coffee shops and or café and pubs.
#
#
# 1. This project explores Boroughs of London. The data were extracted from the following Wikipedia page: https://en.wikipedia.org/wiki/Ethnic_groups_in_London (wikitable sortable jquery-tablesorter)
# 2. Google sheet is used to scrap the table on the Wikipedia page and read into pandas dataframe for further analysis.
# 3. The data will be use to run cluster analyses of London boroughs with the highest African population

# %%
# Exporting necessary libararies
import numpy as np 
import pandas as pd 
import requests

# %% [markdown]
# #### Data
# This project explores Top African Boroughs of London. The data were extracted from the following Wikipedia page: https://en.wikipedia.org/wiki/Ethnic_groups_in_London (wikitable sortable jquery-tablesorter) into a google sheet.
# Google sheet is used to scrap the table on the Wikipedia page and read into pandas dataframe for further analysis.

# %%
# Reading data from excel sheet using pandas 
path = '/content/drive/MyDrive/LondonBlackEthicGroup.xlsx'
lon_com = pd.read_excel(path)
lon_com.head()
# Out:
#    Rank London Borough  ...  Other Black Population  Total Black Population
# 0     1        Lambeth  ...                   14469                   78542
# 1     2      Southwark  ...                   12124                   77511
# 2     3       Lewisham  ...                   12063                   74942
# 3     4        Croydon  ...                   12955                   73256
# 4     5         Newham  ...                    7395                   60256
#
# [5 rows x 6 columns]

# %% [markdown]
# ### Cleaning data

# %%
# Renaming columns from the extracted table
lon_com.rename(columns = {'London Borough' : 'Borough', 'Black African Population' : 'African', 'Black Caribbean Population' : 'Caribbean', 'Other Black Population' : 'Other', 'Total Black Population' : 'Total'}, inplace = True)
lon_com.head()
# Out:
#    Rank    Borough  African  Caribbean  Other  Total
# 0     1    Lambeth    35187      28886  14469  78542
# 1     2  Southwark    47413      17974  12124  77511
# 2     3   Lewisham    32025      30854  12063  74942
# 3     4    Croydon    28981      31320  12955  73256
# 4     5     Newham    37811      15050   7395  60256

# %%
# 5 Boroughs with the highest African population
lon_com2 = lon_com.sort_values(["African"], ascending=False)
lon_com2.head()
# Out:
#    Rank    Borough  African  Caribbean  Other  Total
# 1     2  Southwark    47413      17974  12124  77511
# 4     5     Newham    37811      15050   7395  60256
# 0     1    Lambeth    35187      28886  14469  78542
# 8     9  Greenwich    35164       8051   5440  48655
# 2     3   Lewisham    32025      30854  12063  74942

# %%
lon_com2.drop(columns=['Rank', 'Caribbean', 'Other', 'Total'], inplace = True)
lon_com2.head()
# Out:
#      Borough  African
# 1  Southwark    47413
# 4     Newham    37811
# 0    Lambeth    35187
# 8  Greenwich    35164
# 2   Lewisham    32025

# %% [markdown]
# ### Boroughs Latitude and Logitude

# %%
# Geting the latitude and longitude of Boroughs 

from progressbar import ProgressBar
from geopy.geocoders import Nominatim
from time import sleep

pbar = ProgressBar()
geolocator = Nominatim(user_agent="london_explorer")
for index in pbar(range(0,lon_com2['Borough'].shape[0])):
    address = lon_com2.loc[index,'Borough'] + ", England"
    location = geolocator.geocode(address, timeout = None)
    if (location != None):
        lon_com2.loc[index,'Latitude'] = location.latitude
        lon_com2.loc[index,'Longitude'] = location.longitude
    sleep(1)

print(lon_com2.shape)
lon_com2.head()
# Out:
# 100% (20 of 20) |########################| Elapsed Time: 0:00:38 Time:  0:00:38
# (20, 4)
#      Borough  African   Latitude  Longitude
# 1  Southwark    47413  51.502922  -0.103458
# 4     Newham    37811  51.530000   0.029318
# 0    Lambeth    35187  51.501301  -0.117287
# 8  Greenwich    35164  51.482084  -0.004542
# 2   Lewisham    32025  51.462432  -0.010133

# %%
lon_com2.dropna(how='all')
# Out:
#                    Borough  African   Latitude  Longitude
# 1                Southwark    47413  51.502922  -0.103458
# 4                   Newham    37811  51.530000   0.029318
# 0                  Lambeth    35187  51.501301  -0.117287
# 8                Greenwich    35164  51.482084  -0.004542
# 2                 Lewisham    32025  51.462432  -0.010133
# 3                  Croydon    28981  51.371305  -0.101957
# 11    Barking and Dagenham    28685  51.554117   0.150504
# 7                  Enfield    28222  51.652085  -0.081018
# 6                  Hackney    27976  51.543240  -0.049362
# 5                    Brent    24391  52.018488  -0.723545
# 9                 Haringey    23037  51.587930  -0.105410
# 14                  Barnet    19392  51.653090  -0.200226
# 10          Waltham Forest    18815  51.198159   1.016517
# 12                  Ealing    17299  51.512655  -0.305195
# 13              Wandsworth    14818  51.457027  -0.193261
# 15               Islington    12622  51.538429  -0.099905
# 16               Redbridge    12357  51.576320   0.045410
# 19              Hillingdon    11275  51.542519  -0.448335
# 17  Hammersmith and Fulham    10552  51.492038  -0.223640
# 18                  Merton    10442  51.410870  -0.188097

# %%
lon_com2 = lon_com2.dropna(subset=['Longitude'])

lon_com2 = lon_com2.dropna(subset=['Latitude'])

# %%
Southwark_lat = lon_com2.loc[1, 'Latitude']
Southwark_lng = lon_com2.loc[1, 'Longitude']
Southwark_Borough = lon_com2.loc[1, 'Borough']
print('The latitude and longitude values of {} with Borough {}, are {}, .'.format(Southwark_Borough, Southwark_lat, Southwark_lng))
# Out:
# The latitude and longitude values of Southwark with Borough 51.5029222, are -0.103458, .

# %% [markdown]
# ### Foursquare
# is use to allocate venues and location of venues from the boroughs of london

# %%
# Explore London borough using four square API  

CLIENT_ID = 'QMYW52KAC0CTJNCXLLPH1ZG50CLX442FMCBUYMXFPIQP03DI' # Foursquare ID
CLIENT_SECRET = 'QWX34W1FFO02HMMT5Z2L3V3V21OTB5J52BF2SVBRNGNUHH0M' # Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QMYW52KAC0CTJNCXLLPH1ZG50CLX442FMCBUYMXFPIQP03DI
# CLIENT_SECRET:QWX34W1FFO02HMMT5Z2L3V3V21OTB5J52BF2SVBRNGNUHH0M

# %% [markdown]
# #### Exploring Southwark the Borough with the higest african population

# %%
# Creating the Foursquare get request

LIMIT = 100
radius = 2000
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    Southwark_lat, 
    Southwark_lng, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=QMYW52KAC0CTJNCXLLPH1ZG50CLX442FMCBUYMXFPIQP03DI&client_secret=QWX34W1FFO02HMMT5Z2L3V3V21OTB5J52BF2SVBRNGNUHH0M&v=20180604&ll=51.5029222,-0.103458&radius=2000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '609ff6a6112cbf08883ebca7'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ac518e7f964a52062ab20e3-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'primary': True,
#          'shortName': 'Theater'}],
#        'id': '4ac518e7f964a52062ab20e3',
#        'location': {'address': '66 The Cut',
#         'cc': 'GB',
#         'city': 'Southwark',
#         'country': 'United Kingdom',
#         'crossStreet': 'Greet St',
#         'distance': 277,
#         'formattedAddress': ['66 The Cut (Greet St)',
#          'Southwark',
#          'Greater London',
#          'SE1 8LZ',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.503035994714295,
#           'lng': -0.10746042968216699}],
#         'lat': 51.503035994714295,
#         'lng': -0.10746042968216699,
#         'neighborhood': 'Southwark, London, Greater London',
#         'postalCode': 'SE1 8LZ',
#         'state': 'Greater London'},
#        'name': 'Young Vic',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ac518c4f964a5206da420e3-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d109941735',
#          'name': 'Eastern European Restaurant',
#          'pluralName': 'Eastern European Restaurants',
#          'primary': True,
#          'shortName': 'Eastern European'}],
#        'id': '4ac518c4f964a5206da420e3',
#        'location': {'address': '74 Blackfriars Rd',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'crossStreet': 'The Cut',
#         'distance': 99,
#         'formattedAddress': ['74 Blackfriars Rd (The Cut)',
#          'London',
#          'Greater London',
#          'SE1 8HA',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.503309,
#           'lng': -0.10476}],
#         'lat': 51.503309,
#         'lng': -0.10476,
#         'postalCode': 'SE1 8HA',
#         'state': 'Greater London'},
#        'name': 'Baltic',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5bc9bd972aff31002cc8efe5-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '5bc9bd972aff31002cc8efe5',
#        'location': {'address': '84 Scoresby St',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 156,
#         'formattedAddress': ['84 Scoresby St',
#          'London',
#          'Greater London',
#          'SE1 0XN',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.504326,
#           'lng': -0.103555}],
#         'lat': 51.504326,
#         'lng': -0.103555,
#         'postalCode': 'SE1 0XN',
#         'state': 'Greater London'},
#        'name': 'Origin Coffee',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-553f7203498ead99a5810744-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '553f7203498ead99a5810744',
#        'location': {'address': '2–8 Great Suffolk St',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 334,
#         'formattedAddress': ['2–8 Great Suffolk St',
#          'London',
#          'Greater London',
#          'SE1 0UG',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50555250441724,
#           'lng': -0.10111210137711868}],
#         'lat': 51.50555250441724,
#         'lng': -0.10111210137711868,
#         'postalCode': 'SE1 0UG',
#         'state': 'Greater London'},
#        'name': 'Hilton',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad2f913f964a520ece220e3-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'primary': True,
#          'shortName': 'Grocery Store'}],
#        'id': '4ad2f913f964a520ece220e3',
#        'location': {'address': '90 Southwark St',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'crossStreet': 'Sumner St',
#         'distance': 473,
#         'formattedAddress': ['90 Southwark St (Sumner St)',
#          'London',
#          'Greater London',
#          'SE1 0HX',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50551705,
#           'lng': -0.09804702}],
#         'lat': 51.50551705,
#         'lng': -0.09804702,
#         'postalCode': 'SE1 0HX',
#         'state': 'Greater London'},
#        'name': 'M&S Simply Food',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '572554763'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4acdbc1df964a520dacc20e3-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'primary': True,
#          'shortName': 'Theater'}],
#        'id': '4acdbc1df964a520dacc20e3',
#        'location': {'address': 'The Cut',
#         'cc': 'GB',
#         'city': 'Waterloo',
#         'country': 'United Kingdom',
#         'crossStreet': 'Waterloo Rd',
#         'distance': 439,
#         'formattedAddress': ['The Cut (Waterloo Rd)',
#          'Waterloo',
#          'Greater London',
#          'SE1 8NB',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.502175915094945,
#           'lng': -0.10968642888657347}],
#         'lat': 51.502175915094945,
#         'lng': -0.10968642888657347,
#         'neighborhood': 'Waterloo, London, Greater London',
#         'postalCode': 'SE1 8NB',
#         'state': 'Greater London'},
#        'name': 'The Old Vic',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5811aaaf38fa744ccb1ca703-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b79f9',
#          'name': 'Modern European Restaurant',
#          'pluralName': 'Modern European Restaurants',
#          'primary': True,
#          'shortName': 'Modern European'}],
#        'id': '5811aaaf38fa744ccb1ca703',
#        'location': {'address': '30 Great Guildford St',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 487,
#         'formattedAddress': ['30 Great Guildford St',
#          'London',
#          'Greater London',
#          'SE1 0HS',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50453327171197,
#           'lng': -0.09691316619897597}],
#         'lat': 51.50453327171197,
#         'lng': -0.09691316619897597,
#         'neighborhood': 'Southwark',
#         'postalCode': 'SE1 0HS',
#         'state': 'Greater London'},
#        'name': 'Caravan Bankside',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ac518c3f964a52030a420e3-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'primary': True,
#          'shortName': 'Gastropub'}],
#        'id': '4ac518c3f964a52030a420e3',
#        'location': {'address': '36 The Cut',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'crossStreet': 'Waterloo',
#         'distance': 212,
#         'formattedAddress': ['36 The Cut (Waterloo)',
#          'London',
#          'Greater London',
#          'SE1 8LP',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50338372931985,
#           'lng': -0.10643927677545802}],
#         'lat': 51.50338372931985,
#         'lng': -0.10643927677545802,
#         'postalCode': 'SE1 8LP',
#         'state': 'Greater London'},
#        'name': 'The Anchor & Hope',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ba0b1c4f964a520f57737e3-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4ba0b1c4f964a520f57737e3',
#        'location': {'address': '158 Great Suffolk St',
#         'cc': 'GB',
#         'city': 'Greater London',
#         'country': 'United Kingdom',
#         'distance': 432,
#         'formattedAddress': ['158 Great Suffolk St',
#          'Greater London',
#          'SE1 1PE',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.500715,
#           'lng': -0.098314}],
#         'lat': 51.500715,
#         'lng': -0.098314,
#         'neighborhood': 'Southwark',
#         'postalCode': 'SE1 1PE',
#         'state': 'Greater London'},
#        'name': "Terry's Cafe",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e4fecf52271a1bdc3e53057-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4e4fecf52271a1bdc3e53057',
#        'location': {'address': '20 Lavington St',
#         'cc': 'GB',
#         'city': 'South Bank',
#         'country': 'United Kingdom',
#         'distance': 451,
#         'formattedAddress': ['20 Lavington St',
#          'South Bank',
#          'Greater London',
#          'SE1 0NZ',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50535532261846,
#           'lng': -0.09824182736111206}],
#         'lat': 51.50535532261846,
#         'lng': -0.09824182736111206,
#         'postalCode': 'SE1 0NZ',
#         'state': 'Greater London'},
#        'name': 'citizenM London Bankside',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5d6d66792127810007da7e7a-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '5d6d66792127810007da7e7a',
#        'location': {'address': '40 Blackfriars Road, South Bank, Southwark',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 317,
#         'formattedAddress': ['40 Blackfriars Road, South Bank, Southwark',
#          'London',
#          'Greater London',
#          'SE1 8NY',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50567584468746,
#           'lng': -0.10464829382863172}],
#         'lat': 51.50567584468746,
#         'lng': -0.10464829382863172,
#         'postalCode': 'SE1 8NY',
#         'state': 'Greater London'},
#        'name': 'The Hoxton Southwark',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-577e6189498e861ea3422691-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'id': '53e0feef498e5aac066fd8a9',
#          'name': 'Street Food Gathering',
#          'pluralName': 'Street Food Gatherings',
#          'primary': True,
#          'shortName': 'Street Food Gathering'}],
#        'id': '577e6189498e861ea3422691',
#        'location': {'address': '42 Newington Causeway',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 630,
#         'formattedAddress': ['42 Newington Causeway',
#          'London',
#          'Greater London',
#          'SE1 6DR',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.498318,
#           'lng': -0.098162144}],
#         'lat': 51.498318,
#         'lng': -0.098162144,
#         'neighborhood': 'Borough',
#         'postalCode': 'SE1 6DR',
#         'state': 'Greater London'},
#        'name': 'Mercato Metropolitano',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '219747335'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af323c0f964a5200ceb21e3-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1bc941735',
#          'name': 'Cupcake Shop',
#          'pluralName': 'Cupcake Shops',
#          'primary': True,
#          'shortName': 'Cupcakes'}],
#        'id': '4af323c0f964a5200ceb21e3',
#        'location': {'address': '22 Cornwall Rd',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 503,
#         'formattedAddress': ['22 Cornwall Rd',
#          'London',
#          'Greater London',
#          'SE1 8TW',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50429240982867,
#           'lng': -0.11038668934429101}],
#         'lat': 51.50429240982867,
#         'lng': -0.11038668934429101,
#         'neighborhood': 'London',
#         'postalCode': 'SE1 8TW',
#         'state': 'Greater London'},
#        'name': 'Konditor & Cook Ltd',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ac518d3f964a52076a720e3-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'primary': True,
#          'shortName': 'Art Museum'}],
#        'id': '4ac518d3f964a52076a720e3',
#        'location': {'address': '53 Bankside',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 600,
#         'formattedAddress': ['53 Bankside',
#          'London',
#          'Greater London',
#          'SE1 9TG',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50770408386703,
#           'lng': -0.0994563102722168}],
#         'lat': 51.50770408386703,
#         'lng': -0.0994563102722168,
#         'postalCode': 'SE1 9TG',
#         'state': 'Greater London'},
#        'name': 'Tate Modern',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5418605b498e431f31f3e85b-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '5418605b498e431f31f3e85b',
#        'location': {'address': '20 Upper Ground',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 652,
#         'formattedAddress': ['20 Upper Ground',
#          'London',
#          'Greater London',
#          'SE1 9PD',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.5084036,
#           'lng': -0.1067988}],
#         'lat': 51.5084036,
#         'lng': -0.1067988,
#         'postalCode': 'SE1 9PD',
#         'state': 'Greater London'},
#        'name': 'Sea Containers London',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5197d0e2498e82099af17bdd-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'primary': True,
#          'shortName': 'Theater'}],
#        'id': '5197d0e2498e82099af17bdd',
#        'location': {'address': '77-85 Newington Causeway',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 664,
#         'formattedAddress': ['77-85 Newington Causeway',
#          'London',
#          'Greater London',
#          'SE1 6BD',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.4977793456688,
#           'lng': -0.09860250077684411}],
#         'lat': 51.4977793456688,
#         'lng': -0.09860250077684411,
#         'postalCode': 'SE1 6BD',
#         'state': 'Greater London'},
#        'name': 'Southwark Playhouse',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '59883356'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-576547b6498eaf09a07655da-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'primary': True,
#          'shortName': 'Art Museum'}],
#        'id': '576547b6498eaf09a07655da',
#        'location': {'address': '53 Bankside',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 559,
#         'formattedAddress': ['53 Bankside',
#          'London',
#          'Greater London',
#          'SE1 9TG',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50744699059763,
#           'lng': -0.09992837905883789}],
#         'lat': 51.50744699059763,
#         'lng': -0.09992837905883789,
#         'postalCode': 'SE1 9TG',
#         'state': 'Greater London'},
#        'name': 'Blavatnik Building',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-576536fd498ec1d7f64a59a3-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'primary': True,
#          'shortName': 'Scenic Lookout'}],
#        'id': '576536fd498ec1d7f64a59a3',
#        'location': {'address': '53 Bankside',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'crossStreet': 'Blavatnik Building',
#         'distance': 550,
#         'formattedAddress': ['53 Bankside (Blavatnik Building)',
#          'London',
#          'Greater London',
#          'SE1 9TG',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50740275665009,
#           'lng': -0.10011179066153776}],
#         'lat': 51.50740275665009,
#         'lng': -0.10011179066153776,
#         'postalCode': 'SE1 9TG',
#         'state': 'Greater London'},
#        'name': 'Tate Modern Viewing Level',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a6c780f2347246ed4896a72-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d107941735',
#          'name': 'Argentinian Restaurant',
#          'pluralName': 'Argentinian Restaurants',
#          'primary': True,
#          'shortName': 'Argentinian'}],
#        'id': '5a6c780f2347246ed4896a72',
#        'location': {'address': '132 Southwark Bridge Rd',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 397,
#         'formattedAddress': ['132 Southwark Bridge Rd',
#          'London',
#          'Greater London',
#          'SE1 0DG',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.500664,
#           'lng': -0.099020116}],
#         'lat': 51.500664,
#         'lng': -0.099020116,
#         'neighborhood': 'Southwark',
#         'postalCode': 'SE1 0DG',
#         'state': 'Greater London'},
#        'name': 'Chimichurris',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad64197f964a5201d0621e3-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'primary': True,
#          'shortName': 'Theater'}],
#        'id': '4ad64197f964a5201d0621e3',
#        'location': {'address': '21 New Globe Walk',
#         'cc': 'GB',
#         'city': 'South Bank',
#         'country': 'United Kingdom',
#         'crossStreet': 'Bankside',
#         'distance': 723,
#         'formattedAddress': ['21 New Globe Walk (Bankside)',
#          'South Bank',
#          'Greater London',
#          'SE1 9DT',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.508099,
#           'lng': -0.09715}],
#         'lat': 51.508099,
#         'lng': -0.09715,
#         'neighborhood': 'South Bank, London, Greater London',
#         'postalCode': 'SE1 9DT',
#         'state': 'Greater London'},
#        'name': "Shakespeare's Globe Theatre",
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33413232'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57f3baea498efae5781eca28-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'primary': True,
#          'shortName': 'Beer Bar'}],
#        'id': '57f3baea498efae5781eca28',
#        'location': {'address': '40-42 Newington Causeway',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 559,
#         'formattedAddress': ['40-42 Newington Causeway',
#          'London',
#          'Greater London',
#          'SE1 6DR',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49871478592709,
#           'lng': -0.09903581206029025}],
#         'lat': 51.49871478592709,
#         'lng': -0.09903581206029025,
#         'postalCode': 'SE1 6DR',
#         'state': 'Greater London'},
#        'name': 'The Italian Job',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b141334f964a520de9c23e3-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'primary': True,
#          'shortName': 'Movie Theater'}],
#        'id': '4b141334f964a520de9c23e3',
#        'location': {'address': '1 Charlie Chaplin Walk, South Bank',
#         'cc': 'GB',
#         'city': 'Waterloo',
#         'country': 'United Kingdom',
#         'distance': 734,
#         'formattedAddress': ['1 Charlie Chaplin Walk, South Bank',
#          'Waterloo',
#          'Greater London',
#          'SE1 8XR',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.5049953,
#           'lng': -0.1135287}],
#         'lat': 51.5049953,
#         'lng': -0.1135287,
#         'postalCode': 'SE1 8XR',
#         'state': 'Greater London'},
#        'name': 'ODEON BFI IMAX',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-542befc0498ee6f304d669e8-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '542befc0498ee6f304d669e8',
#        'location': {'address': '63 Union St',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 620,
#         'formattedAddress': ['63 Union St',
#          'London',
#          'Greater London',
#          'SE1 1SG',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.503849,
#           'lng': -0.094635}],
#         'lat': 51.503849,
#         'lng': -0.094635,
#         'postalCode': 'SE1 1SG',
#         'state': 'Greater London'},
#        'name': 'The Gentlemen Baristas',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5b4736f5835c9a002c447b88-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#           'suffix': '.png'},
#          'id': '4def73e84765ae376e57713a',
#          'name': 'Portuguese Restaurant',
#          'pluralName': 'Portuguese Restaurants',
#          'primary': True,
#          'shortName': 'Portuguese'}],
#        'id': '5b4736f5835c9a002c447b88',
#        'location': {'address': '32 Southwark St',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'crossStreet': 'First Floor',
#         'distance': 758,
#         'formattedAddress': ['32 Southwark St (First Floor)',
#          'London',
#          'Greater London',
#          'SE1 1TU',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.504752,
#           'lng': -0.092908}],
#         'lat': 51.504752,
#         'lng': -0.092908,
#         'postalCode': 'SE1 1TU',
#         'state': 'Greater London'},
#        'name': 'Casa do Frango',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d808b1f1013236a14aa8935-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'id': '53e0feef498e5aac066fd8a9',
#          'name': 'Street Food Gathering',
#          'pluralName': 'Street Food Gatherings',
#          'primary': True,
#          'shortName': 'Street Food Gathering'}],
#        'id': '4d808b1f1013236a14aa8935',
#        'location': {'address': 'Union St',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 609,
#         'formattedAddress': ['Union St',
#          'London',
#          'Greater London',
#          'SE1 0AB',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.504505,
#           'lng': -0.09503603}],
#         'lat': 51.504505,
#         'lng': -0.09503603,
#         'neighborhood': 'Southwark',
#         'postalCode': 'SE1 0AB',
#         'state': 'Greater London'},
#        'name': 'Flat Iron Square',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57ae3585498e2484c4c394e1-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '57ae3585498e2484c4c394e1',
#        'location': {'address': '44 Southwark St',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 686,
#         'formattedAddress': ['44 Southwark St',
#          'London',
#          'Greater London',
#          'SE1 1UN',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.504846,
#           'lng': -0.09405}],
#         'lat': 51.504846,
#         'lng': -0.09405,
#         'postalCode': 'SE1 1UN',
#         'state': 'Greater London'},
#        'name': "'O ver",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-59c6f1f2db1d8114b5e92e87-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1be941735',
#          'name': 'Latin American Restaurant',
#          'pluralName': 'Latin American Restaurants',
#          'primary': True,
#          'shortName': 'Latin American'}],
#        'id': '59c6f1f2db1d8114b5e92e87',
#        'location': {'address': '4-5 London Rd',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 536,
#         'formattedAddress': ['4-5 London Rd',
#          'London',
#          'Greater London',
#          'SE1 6JZ',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.4981401,
#           'lng': -0.104369}],
#         'lat': 51.4981401,
#         'lng': -0.104369,
#         'postalCode': 'SE1 6JZ',
#         'state': 'Greater London'},
#        'name': 'Paladar',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '462692623'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bc3294d4cdfc9b662ea9621-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '4bc3294d4cdfc9b662ea9621',
#        'location': {'address': '1 Gladstone St',
#         'cc': 'GB',
#         'city': 'Elephant & Castle',
#         'country': 'United Kingdom',
#         'distance': 613,
#         'formattedAddress': ['1 Gladstone St',
#          'Elephant & Castle',
#          'Greater London',
#          'SE1 6EY',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.497415847571645,
#           'lng': -0.10376726843493472}],
#         'lat': 51.497415847571645,
#         'lng': -0.10376726843493472,
#         'postalCode': 'SE1 6EY',
#         'state': 'Greater London'},
#        'name': 'Albert Arms',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5888f21eec980f1cabe2602f-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'primary': True,
#          'shortName': 'Bar'}],
#        'id': '5888f21eec980f1cabe2602f',
#        'location': {'address': '34 Lower Marsh',
#         'cc': 'GB',
#         'city': 'Waterloo',
#         'country': 'United Kingdom',
#         'distance': 616,
#         'formattedAddress': ['34 Lower Marsh',
#          'Waterloo',
#          'Greater London',
#          'SE1 7RG',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.5011883188609,
#           'lng': -0.11190893852238705}],
#         'lat': 51.5011883188609,
#         'lng': -0.11190893852238705,
#         'postalCode': 'SE1 7RG',
#         'state': 'Greater London'},
#        'name': 'Vaulty Towers',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d8f3fd46174a093edbad9e3-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'primary': True,
#          'shortName': 'Scenic Lookout'}],
#        'id': '4d8f3fd46174a093edbad9e3',
#        'location': {'address': 'Lambeth Bridge to London Bridge',
#         'cc': 'GB',
#         'city': 'Greater London',
#         'country': 'United Kingdom',
#         'distance': 788,
#         'formattedAddress': ['Lambeth Bridge to London Bridge',
#          'Greater London',
#          'SE 1 9',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.508308050234476,
#           'lng': -0.11085254445104126}],
#         'lat': 51.508308050234476,
#         'lng': -0.11085254445104126,
#         'postalCode': 'SE 1 9',
#         'state': 'Greater London'},
#        'name': "The Queen's Walk",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bf7c1814a67c928a21a24cf-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_cheese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e951735',
#          'name': 'Cheese Shop',
#          'pluralName': 'Cheese Shops',
#          'primary': True,
#          'shortName': 'Cheese Shop'}],
#        'id': '4bf7c1814a67c928a21a24cf',
#        'location': {'address': '6 Park St',
#         'cc': 'GB',
#         'city': 'Greater London',
#         'country': 'United Kingdom',
#         'distance': 876,
#         'formattedAddress': ['6 Park St',
#          'Greater London',
#          'SE1 9AB',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50543821400243,
#           'lng': -0.09147352390458788}],
#         'lat': 51.50543821400243,
#         'lng': -0.09147352390458788,
#         'postalCode': 'SE1 9AB',
#         'state': 'Greater London'},
#        'name': "Neal's Yard Dairy",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57025a60498e2196f62e9548-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '57025a60498e2196f62e9548',
#        'location': {'address': '20 Lower Marsh',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'crossStreet': 'Grindal St',
#         'distance': 705,
#         'formattedAddress': ['20 Lower Marsh (Grindal St)',
#          'London',
#          'Greater London',
#          'SE1 7RJ',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.500636,
#           'lng': -0.112947}],
#         'lat': 51.500636,
#         'lng': -0.112947,
#         'postalCode': 'SE1 7RJ',
#         'state': 'Greater London'},
#        'name': 'Coleman Coffee Roasters',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bee6b07e8c3c928afac9892-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'primary': True,
#          'shortName': 'Scenic Lookout'}],
#        'id': '4bee6b07e8c3c928afac9892',
#        'location': {'address': '58-72 Upper Ground',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 802,
#         'formattedAddress': ['58-72 Upper Ground',
#          'London',
#          'Greater London',
#          'SE1 9LT',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50829670344467,
#           'lng': -0.11118003368266494}],
#         'lat': 51.50829670344467,
#         'lng': -0.11118003368266494,
#         'postalCode': 'SE1 9LT',
#         'state': 'Greater London'},
#        'name': 'The Southbank Observation Point',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad9a8acf964a5205f1a21e3-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4ad9a8acf964a5205f1a21e3',
#        'location': {'address': '2 Park St',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'crossStreet': 'The Borough',
#         'distance': 879,
#         'formattedAddress': ['2 Park St (The Borough)',
#          'London',
#          'Greater London',
#          'SE1 9AB',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.505536,
#           'lng': -0.09148}],
#         'lat': 51.505536,
#         'lng': -0.09148,
#         'postalCode': 'SE1 9AB',
#         'state': 'Greater London'},
#        'name': 'Monmouth Coffee Company',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-542eec4e498ee31baa076ef7-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'primary': True,
#          'shortName': 'Theater'}],
#        'id': '542eec4e498ee31baa076ef7',
#        'location': {'address': 'Upper Ground',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 832,
#         'formattedAddress': ['Upper Ground',
#          'London',
#          'Greater London',
#          'SE1 9PX',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50716652355835,
#           'lng': -0.11335015296936035}],
#         'lat': 51.50716652355835,
#         'lng': -0.11335015296936035,
#         'postalCode': 'SE1 9PX',
#         'state': 'Greater London'},
#        'name': 'Dorfman Theatre',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53e41c3d498eaa1264f9f77e-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/skate_park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d167941735',
#          'name': 'Skate Park',
#          'pluralName': 'Skate Parks',
#          'primary': True,
#          'shortName': 'Skate Park'}],
#        'id': '53e41c3d498eaa1264f9f77e',
#        'location': {'address': 'Station Approach Rd',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 768,
#         'formattedAddress': ['Station Approach Rd',
#          'London',
#          'Greater London',
#          'SE1 8SW',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50067766931536,
#           'lng': -0.11394401690060052}],
#         'lat': 51.50067766931536,
#         'lng': -0.11394401690060052,
#         'postalCode': 'SE1 8SW',
#         'state': 'Greater London'},
#        'name': 'House of Vans',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ac518d3f964a52078a720e3-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'primary': True,
#          'shortName': 'History Museum'}],
#        'id': '4ac518d3f964a52078a720e3',
#        'location': {'address': 'Lambeth Rd',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 851,
#         'formattedAddress': ['Lambeth Rd',
#          'London',
#          'Greater London',
#          'SE1 6HZ',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49598474204294,
#           'lng': -0.10864157985065033}],
#         'lat': 51.49598474204294,
#         'lng': -0.10864157985065033,
#         'neighborhood': 'Lambeth, London, Greater London',
#         'postalCode': 'SE1 6HZ',
#         'state': 'Greater London'},
#        'name': 'Imperial War Museum',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a7dd90e123a197f906e8ef8-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '5a7dd90e123a197f906e8ef8',
#        'location': {'address': 'The Queen’s Walk',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'crossStreet': 'Blackfriars Railway Station',
#         'distance': 631,
#         'formattedAddress': ['The Queen’s Walk (Blackfriars Railway Station)',
#          'London',
#          'Greater London',
#          'SE1 9JH',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50857847937478,
#           'lng': -0.10281580935644521}],
#         'lat': 51.50857847937478,
#         'lng': -0.10281580935644521,
#         'postalCode': 'SE1 9JH',
#         'state': 'Greater London'},
#        'name': 'FCB Coffee',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c26116ea852c928bae0e56c-38',
# ...
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.51358969,
#           'lng': -0.09529666}],
#         'lat': 51.51358969,
#         'lng': -0.09529666,
#         'postalCode': 'EC4M 9AF',
#         'state': 'Greater London'},
#        'name': 'M&S Simply Food',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '571060761'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4eb14bef9a52c49f4cec6b59-88',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4eb14bef9a52c49f4cec6b59',
#        'location': {'address': "1-2 Serjeants' Inn",
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'crossStreet': 'Fleet St',
#         'distance': 1261,
#         'formattedAddress': ["1-2 Serjeants' Inn (Fleet St)",
#          'London',
#          'Greater London',
#          'EC4Y 1AG',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.513738211581575,
#           'lng': -0.10887801319023883}],
#         'lat': 51.513738211581575,
#         'lng': -0.10887801319023883,
#         'postalCode': 'EC4Y 1AG',
#         'state': 'Greater London'},
#        'name': 'Apex Temple Court Hotel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53f3c373498e9483f307872e-89',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'primary': True,
#          'shortName': 'Cocktail'}],
#        'id': '53f3c373498e9483f307872e',
#        'location': {'address': 'Arch 2, Green Dragon Court',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'crossStreet': 'Borough Market',
#         'distance': 1033,
#         'formattedAddress': ['Arch 2, Green Dragon Court (Borough Market)',
#          'London',
#          'Greater London',
#          'SE1 9EW',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.505694599585965,
#           'lng': -0.08922717404948362}],
#         'lat': 51.505694599585965,
#         'lng': -0.08922717404948362,
#         'postalCode': 'SE1 9EW',
#         'state': 'Greater London'},
#        'name': 'Whiskey Ginger',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-511a3e11e4b0f04136fb9755-90',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/peruvian_',
#           'suffix': '.png'},
#          'id': '4eb1bfa43b7b52c0e1adc2e8',
#          'name': 'Peruvian Restaurant',
#          'pluralName': 'Peruvian Restaurants',
#          'primary': True,
#          'shortName': 'Peruvian'}],
#        'id': '511a3e11e4b0f04136fb9755',
#        'location': {'address': '103 Newington Butts',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 1129,
#         'formattedAddress': ['103 Newington Butts',
#          'London',
#          'Greater London',
#          'SE1 6SF',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49288730706875,
#           'lng': -0.10106320200506204}],
#         'lat': 51.49288730706875,
#         'lng': -0.10106320200506204,
#         'neighborhood': 'Elephant and Castle',
#         'postalCode': 'SE1 6SF',
#         'state': 'Greater London'},
#        'name': 'Sabor Peruano',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bc45d99b492d13a0de1a960-91',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_butcher_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11d951735',
#          'name': 'Butcher',
#          'pluralName': 'Butchers',
#          'primary': True,
#          'shortName': 'Butcher'}],
#        'id': '4bc45d99b492d13a0de1a960',
#        'location': {'address': '72 Watling St',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 1311,
#         'formattedAddress': ['72 Watling St',
#          'London',
#          'Greater London',
#          'EC4M 9BJ',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.51303235326847,
#           'lng': -0.09373702135804958}],
#         'lat': 51.51303235326847,
#         'lng': -0.09373702135804958,
#         'neighborhood': 'City of London',
#         'postalCode': 'EC4M 9BJ',
#         'state': 'Greater London'},
#        'name': 'Porterford Butchers',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53b15736498e1cdd0eb1d95b-92',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'primary': True,
#          'shortName': 'Cocktail'}],
#        'id': '53b15736498e1cdd0eb1d95b',
#        'location': {'address': '13 Well Ct',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'crossStreet': 'Bow Ln',
#         'distance': 1358,
#         'formattedAddress': ['13 Well Ct (Bow Ln)',
#          'London',
#          'Greater London',
#          'EC4M 9DN',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.513264,
#           'lng': -0.093039}],
#         'lat': 51.513264,
#         'lng': -0.093039,
#         'postalCode': 'EC4M 9DN',
#         'state': 'Greater London'},
#        'name': 'The Merchant House',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bc88fbf8b7c9c74915938cf-93',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'primary': True,
#          'shortName': 'Trail'}],
#        'id': '4bc88fbf8b7c9c74915938cf',
#        'location': {'address': 'Lower Thames St',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 1345,
#         'formattedAddress': ['Lower Thames St',
#          'London',
#          'Greater London',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50881048656039,
#           'lng': -0.08649587631225586}],
#         'lat': 51.50881048656039,
#         'lng': -0.08649587631225586,
#         'state': 'Greater London'},
#        'name': 'Thames Path',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c0ce9597189c928961ed6b6-94',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d15a941735',
#          'name': 'Garden',
#          'pluralName': 'Gardens',
#          'primary': True,
#          'shortName': 'Garden'}],
#        'id': '4c0ce9597189c928961ed6b6',
#        'location': {'address': 'Horseguards Ave',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 1400,
#         'formattedAddress': ['Horseguards Ave',
#          'London',
#          'Greater London',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.506353735053956,
#           'lng': -0.12289968472873267}],
#         'lat': 51.506353735053956,
#         'lng': -0.12289968472873267,
#         'neighborhood': 'Westminster',
#         'state': 'Greater London'},
#        'name': 'Whitehall Gardens',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f5cf385e4b0c5418c18966b-95',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_roofdeck_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d133951735',
#          'name': 'Roof Deck',
#          'pluralName': 'Roof Decks',
#          'primary': True,
#          'shortName': 'Roof Deck'}],
#        'id': '4f5cf385e4b0c5418c18966b',
#        'location': {'address': 'One New Change',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 1334,
#         'formattedAddress': ['One New Change',
#          'London',
#          'Greater London',
#          'EC4M 9AF',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.51391176437131,
#           'lng': -0.09577454922475599}],
#         'lat': 51.51391176437131,
#         'lng': -0.09577454922475599,
#         'neighborhood': 'City of London',
#         'postalCode': 'EC4M 9AF',
#         'state': 'Greater London'},
#        'name': 'One New Change Rooftop',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-508ea192e4b0c9eb73474495-96',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'id': '4e0e22f5a56208c4ea9a85a0',
#          'name': 'Distillery',
#          'pluralName': 'Distilleries',
#          'primary': True,
#          'shortName': 'Distillery'}],
#        'id': '508ea192e4b0c9eb73474495',
#        'location': {'address': '22-24 Bride Ln',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'distance': 1235,
#         'formattedAddress': ['22-24 Bride Ln',
#          'London',
#          'Greater London',
#          'EC4Y 8DT',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.51398752927309,
#           'lng': -0.10488527018294462}],
#         'lat': 51.51398752927309,
#         'lng': -0.10488527018294462,
#         'postalCode': 'EC4Y 8DT',
#         'state': 'Greater London'},
#        'name': 'City of London Distillery',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '91293088'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bc5a1644a9aa593daab067b-97',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'primary': True,
#          'shortName': 'Grocery Store'}],
#        'id': '4bc5a1644a9aa593daab067b',
#        'location': {'address': 'More London Riverside',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'crossStreet': '6 Tooley St',
#         'distance': 1431,
#         'formattedAddress': ['More London Riverside (6 Tooley St)',
#          'London',
#          'Greater London',
#          'SE1 2DA',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.50511656,
#           'lng': -0.08310302}],
#         'lat': 51.50511656,
#         'lng': -0.08310302,
#         'postalCode': 'SE1 2DA',
#         'state': 'Greater London'},
#        'name': 'M&S Simply Food',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '570558984'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b9e3908f964a520f6d236e3-98',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d15a941735',
#          'name': 'Garden',
#          'pluralName': 'Gardens',
#          'primary': True,
#          'shortName': 'Garden'}],
#        'id': '4b9e3908f964a520f6d236e3',
#        'location': {'address': 'Victoria Embankment',
#         'cc': 'GB',
#         'city': 'London',
#         'country': 'United Kingdom',
#         'crossStreet': 'btwn Villiers St & Savoy St',
#         'distance': 1414,
#         'formattedAddress': ['Victoria Embankment (btwn Villiers St & Savoy St)',
#          'London',
#          'Greater London',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.508135223356234,
#           'lng': -0.12207889450158034}],
#         'lat': 51.508135223356234,
#         'lng': -0.12207889450158034,
#         'state': 'Greater London'},
#        'name': 'Victoria Embankment Gardens',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '53401191'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-510bf9f5e4b00192ab00a653-99',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'primary': True,
#          'shortName': 'Convenience Store'}],
#        'id': '510bf9f5e4b00192ab00a653',
#        'location': {'address': '128-132 Walworth Rd',
#         'cc': 'GB',
#         'city': 'Elephant & Castle',
#         'country': 'United Kingdom',
#         'distance': 1344,
#         'formattedAddress': ['128-132 Walworth Rd',
#          'Elephant & Castle',
#          'Greater London',
#          'SE17 1JL',
#          'United Kingdom'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 51.49138673642402,
#           'lng': -0.09771888630493422}],
#         'lat': 51.49138673642402,
#         'lng': -0.09771888630493422,
#         'postalCode': 'SE17 1JL',
#         'state': 'Greater London'},
#        'name': 'Longdan Express',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Southwark, London',
#   'headerLocation': 'Southwark',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 51.52092221800002,
#     'lng': -0.07459512526187437},
#    'sw': {'lat': 51.484922181999984, 'lng': -0.13232087473812562}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 236}}

# %%
# Extracting venues categories
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
from pandas.io.json import json_normalize

# %%
# Extracting json file to pada dataframe 
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON
# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues = nearby_venues.loc[:, filtered_columns]
# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
nearby_venues.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
#               name                   categories        lat       lng
# 0        Young Vic                      Theater  51.503036 -0.107460
# 1           Baltic  Eastern European Restaurant  51.503309 -0.104760
# 2    Origin Coffee                  Coffee Shop  51.504326 -0.103555
# 3           Hilton                        Hotel  51.505553 -0.101112
# 4  M&S Simply Food                Grocery Store  51.505517 -0.098047

# %%
nearby_venues_Southwark_unique = nearby_venues['categories'].value_counts().to_frame(name='Amount')
nearby_venues_Southwark_unique.head()
# Out:
#                 Amount
# Coffee Shop         10
# Hotel                8
# Theater              7
# Scenic Lookout       4
# Beer Bar             4

# %% [markdown]
# ### Exploring london boroughs on the dataframe lon_com2

# %%
# Nearby venues from neighbours in London
def getNearbyVenues(names, latitudes, longitudes, radius=2500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
lon_venues = getNearbyVenues(names=lon_com2['Borough'],
                                   latitudes=lon_com2['Latitude'],
                                   longitudes=lon_com2['Longitude']
                                  )
# Out:
# Southwark
# Newham
# Lambeth
# Greenwich
# Lewisham
# Croydon
# Barking and Dagenham
# Enfield
# Hackney
# Brent
# Haringey
# Barnet
# Waltham Forest
# Ealing
# Wandsworth
# Islington
# Redbridge
# Hillingdon
# Hammersmith and Fulham
# Merton

# %%
# df size

print(lon_venues.shape)
# Out:
# (1595, 7)

# %% [markdown]
# ### list of london venues

# %%
lon_venues.head()
# Out:
#   Neighborhood  ...              Venue Category
# 0    Southwark  ...                     Theater
# 1    Southwark  ...                       Hotel
# 2    Southwark  ...               Grocery Store
# 3    Southwark  ...  Modern European Restaurant
# 4    Southwark  ...       Street Food Gathering
#
# [5 rows x 7 columns]

# %% [markdown]
# #### number of venues explore for each neighborhood

# %%
# numbers of venue per neighbourhood 
lon_venues.groupby('Neighborhood').count()
# Out:
#                         Neighborhood Latitude  ...  Venue Category
# Neighborhood                                   ...
# Barking and Dagenham                       36  ...              36
# Barnet                                     44  ...              44
# Brent                                      61  ...              61
# Croydon                                    89  ...              89
# Ealing                                    100  ...             100
# Enfield                                    61  ...              61
# Greenwich                                 100  ...             100
# Hackney                                   100  ...             100
# Hammersmith and Fulham                    100  ...             100
# Haringey                                  100  ...             100
# Hillingdon                                 70  ...              70
# Islington                                 100  ...             100
# Lambeth                                   100  ...             100
# Lewisham                                  100  ...             100
# Merton                                     81  ...              81
# Newham                                    100  ...             100
# Redbridge                                  50  ...              50
# Southwark                                 100  ...             100
# Waltham Forest                              3  ...               3
# Wandsworth                                100  ...             100
#
# [20 rows x 6 columns]

# %%
print('There are {} uniques categories.'.format(len(lon_venues['Venue Category'].unique())))
# Out:
# There are 227 uniques categories.

# %%
lon_venues_unique_count = lon_venues['Venue Category'].value_counts().to_frame(name='Amount')
lon_venues_unique_count
# Out:
#                     Amount
# Pub                    171
# Coffee Shop            105
# Park                    86
# Café                    71
# Grocery Store           55
# ...                    ...
# BBQ Joint                1
# Antique Shop             1
# Stationery Store         1
# Athletics & Sports       1
# Jazz Club                1
#
# [227 rows x 1 columns]

# %% [markdown]
# ##### Clustering using the aboved processed data

# %%
address = 'London, United Kingdom'
geolocator = Nominatim(user_agent="ln_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of London are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of London are 51.5073219, -0.1276474.

# %% [markdown]
# #### Visualization

# %%
import folium
map_london = folium.Map(location=[latitude, longitude], zoom_start=9)
map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_5ee05ea957fe41a9be9786e6b05b6ad9%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5ee05ea957fe41a9be9786e6b05b6ad9%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_5ee05ea957fe41a9be9786e6b05b6ad9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_5ee05ea957fe41a9be9786e6b05b6ad9%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B51.5073219%2C%20-0.1276474%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%209%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_42765dae612d4cc1bb3860ad2918c7a7%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20 ...

# %%
# Adding markers to map

for lat, lng, label in zip(lon_com2['Latitude'], lon_com2['Longitude'], lon_com2['Borough']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=20,
        popup=label,
        color='yellow',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_london)
map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_5ee05ea957fe41a9be9786e6b05b6ad9%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5ee05ea957fe41a9be9786e6b05b6ad9%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_5ee05ea957fe41a9be9786e6b05b6ad9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_5ee05ea957fe41a9be9786e6b05b6ad9%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B51.5073219%2C%20-0.1276474%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%209%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_42765dae612d4cc1bb3860ad2918c7a7%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20 ...

# %% [markdown]
# ##### Analyzing each neighborhood using One Hot Encoding

# %%
# numbers of category found

# one hot encoding
lon_onehot = pd.get_dummies(lon_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
lon_onehot['Neighborhood'] = lon_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [lon_onehot.columns[-1]] + list(lon_onehot.columns[:-1])
lon_onehot = lon_onehot[fixed_columns]

lon_onehot.head()
# Out:
#   Neighborhood  Airport Terminal  ...  Yoga Studio  Zoo Exhibit
# 0    Southwark                 0  ...            0            0
# 1    Southwark                 0  ...            0            0
# 2    Southwark                 0  ...            0            0
# 3    Southwark                 0  ...            0            0
# 4    Southwark                 0  ...            0            0
#
# [5 rows x 228 columns]

# %%
lon_onehot.shape
# Out:
# (1595, 228)

# %% [markdown]
# #### check for venues with African brand or African name

# %%
lon_onehot.loc[lon_onehot['African'] != 0]

# %%
lon_grouped = lon_onehot.groupby('Neighborhood').mean().reset_index()
lon_grouped.head()
# Out:
#            Neighborhood  Airport Terminal  ...  Yoga Studio  Zoo Exhibit
# 0  Barking and Dagenham               0.0  ...          0.0          0.0
# 1                Barnet               0.0  ...          0.0          0.0
# 2                 Brent               0.0  ...          0.0          0.0
# 3               Croydon               0.0  ...          0.0          0.0
# 4                Ealing               0.0  ...          0.0          0.0
#
# [5 rows x 228 columns]

# %%
lon_grouped.shape
# Out:
# (20, 228)

# %% [markdown]
# #### 10 top venues for each Neighborhood

# %%
# 10 top venues in each neighborhood

num_top_venues = 10 # Top common venues needed
for hood in lon_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = lon_grouped[lon_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue', 'freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending = False).reset_index(drop = True).head(num_top_venues))
    print('\n')
# Out:
# ----Barking and Dagenham----
#                   venue  freq
# 0         Grocery Store  0.17
# 1           Supermarket  0.11
# 2                  Park  0.08
# 3           Gas Station  0.08
# 4                   Pub  0.08
# 5              Platform  0.03
# 6            Restaurant  0.03
# 7           Pizza Place  0.03
# 8  Gym / Fitness Center  0.03
# 9     Food & Drink Shop  0.03
#
#
# ----Barnet----
#            venue  freq
# 0            Pub  0.16
# 1    Coffee Shop  0.11
# 2           Park  0.07
# 3  Grocery Store  0.07
# 4       Pharmacy  0.05
# 5  Train Station  0.05
# 6    Pizza Place  0.05
# 7      Bookstore  0.05
# 8    Golf Course  0.05
# 9           Café  0.02
#
#
# ----Brent----
#                     venue  freq
# 0           Grocery Store  0.10
# 1          Clothing Store  0.07
# 2                     Pub  0.07
# 3                   Hotel  0.05
# 4    Fast Food Restaurant  0.05
# 5             Supermarket  0.03
# 6      Italian Restaurant  0.03
# 7                     Gym  0.03
# 8  Furniture / Home Store  0.03
# 9             Coffee Shop  0.03
#
#
# ----Croydon----
#                       venue  freq
# 0                     Hotel  0.08
# 1                       Pub  0.08
# 2             Grocery Store  0.07
# 3               Coffee Shop  0.07
# 4                      Park  0.07
# 5         Indian Restaurant  0.03
# 6                      Café  0.03
# 7  Mediterranean Restaurant  0.02
# 8               Supermarket  0.02
# 9                  Platform  0.02
#
#
# ----Ealing----
#                    venue  freq
# 0                    Pub  0.14
# 1            Coffee Shop  0.09
# 2                   Park  0.08
# 3     Italian Restaurant  0.05
# 4                  Hotel  0.05
# 5            Pizza Place  0.03
# 6           Burger Joint  0.03
# 7                   Café  0.03
# 8  Vietnamese Restaurant  0.02
# 9            Supermarket  0.02
#
#
# ----Enfield----
#                   venue  freq
# 0                   Pub  0.16
# 1           Coffee Shop  0.10
# 2           Supermarket  0.10
# 3    Turkish Restaurant  0.05
# 4         Train Station  0.05
# 5         Grocery Store  0.05
# 6     Indian Restaurant  0.03
# 7                  Park  0.03
# 8     Fish & Chips Shop  0.03
# 9  Gym / Fitness Center  0.03
#
#
# ----Greenwich----
#                   venue  freq
# 0                   Pub  0.13
# 1                  Park  0.05
# 2                   Bar  0.05
# 3                Garden  0.04
# 4    Turkish Restaurant  0.03
# 5           Coffee Shop  0.03
# 6                  Café  0.03
# 7               Brewery  0.03
# 8  Gym / Fitness Center  0.03
# 9        Farmers Market  0.02
#
#
# ----Hackney----
#             venue  freq
# 0             Pub  0.13
# 1     Coffee Shop  0.09
# 2          Bakery  0.07
# 3            Café  0.07
# 4            Park  0.06
# 5      Restaurant  0.04
# 6         Brewery  0.03
# 7   Historic Site  0.02
# 8  Farmers Market  0.02
# 9        Beer Bar  0.02
#
#
# ----Hammersmith and Fulham----
#                        venue  freq
# 0                        Pub  0.11
# 1                       Café  0.09
# 2                     Bakery  0.06
# 3                Coffee Shop  0.06
# 4         Italian Restaurant  0.04
# 5                       Park  0.03
# 6  Middle Eastern Restaurant  0.03
# 7                  Gastropub  0.03
# 8          Indian Restaurant  0.02
# 9             Farmers Market  0.02
#
#
# ----Haringey----
#                 venue  freq
# 0                 Pub  0.11
# 1  Turkish Restaurant  0.10
# 2         Coffee Shop  0.09
# 3                Park  0.08
# 4                Café  0.07
# 5              Bakery  0.05
# 6  Italian Restaurant  0.03
# 7       Grocery Store  0.03
# 8               Trail  0.02
# 9       Garden Center  0.02
#
#
# ----Hillingdon----
#                   venue  freq
# 0           Coffee Shop  0.11
# 1                   Pub  0.09
# 2         Grocery Store  0.06
# 3              Pharmacy  0.04
# 4                   Gym  0.04
# 5        Clothing Store  0.04
# 6  Fast Food Restaurant  0.03
# 7        Sandwich Place  0.03
# 8            Restaurant  0.03
# 9  Gym / Fitness Center  0.03
#
#
# ----Islington----
#             venue  freq
# 0             Pub  0.14
# 1     Coffee Shop  0.08
# 2            Café  0.08
# 3          Bakery  0.04
# 4            Park  0.03
# 5           Canal  0.03
# 6     Pizza Place  0.03
# 7       Bookstore  0.02
# 8  Breakfast Spot  0.02
# 9    Burger Joint  0.02
#
#
# ----Lambeth----
#                    venue  freq
# 0                  Hotel  0.07
# 1              Bookstore  0.05
# 2                  Plaza  0.04
# 3                Theater  0.04
# 4         Scenic Lookout  0.03
# 5                 Garden  0.03
# 6             Art Museum  0.03
# 7                   Park  0.03
# 8                 Lounge  0.03
# 9  Street Food Gathering  0.02
#
#
# ----Lewisham----
#                venue  freq
# 0                Pub  0.12
# 1        Coffee Shop  0.08
# 2               Café  0.07
# 3               Park  0.05
# 4                Bar  0.04
# 5          Gastropub  0.04
# 6             Garden  0.04
# 7  Fish & Chips Shop  0.02
# 8       Cocktail Bar  0.02
# 9      Deli / Bodega  0.02
#
#
# ----Merton----
#                  venue  freq
# 0                  Pub  0.12
# 1                 Park  0.09
# 2     Sushi Restaurant  0.05
# 3  Lebanese Restaurant  0.04
# 4                 Café  0.04
# 5   Italian Restaurant  0.04
# 6          Coffee Shop  0.04
# 7                  Bar  0.04
# 8         Burger Joint  0.04
# 9        Movie Theater  0.02
#
#
# ----Newham----
#                venue  freq
# 0                Pub  0.08
# 1  Indian Restaurant  0.06
# 2              Hotel  0.06
# 3        Coffee Shop  0.05
# 4               Café  0.05
# 5        Supermarket  0.05
# 6      Grocery Store  0.04
# 7           Platform  0.03
# 8               Park  0.03
# 9        Bus Station  0.02
#
#
# ----Redbridge----
#                 venue  freq
# 0                 Pub  0.16
# 1       Grocery Store  0.12
# 2                Park  0.10
# 3         Pizza Place  0.06
# 4   Indian Restaurant  0.06
# 5               Hotel  0.04
# 6              Bakery  0.04
# 7  Turkish Restaurant  0.04
# 8          Restaurant  0.04
# 9         Coffee Shop  0.04
#
#
# ----Southwark----
#             venue  freq
# 0  Scenic Lookout  0.06
# 1           Hotel  0.06
# 2             Pub  0.04
# 3         Theater  0.04
# 4          Garden  0.04
# 5     Coffee Shop  0.04
# 6           Plaza  0.03
# 7     Pizza Place  0.03
# 8   Grocery Store  0.03
# 9            Park  0.03
#
#
# ----Waltham Forest----
#                      venue  freq
# 0                      Pub  0.33
# 1                Gastropub  0.33
# 2          Vacation Rental  0.33
# 3         Airport Terminal  0.00
# 4         Pedestrian Plaza  0.00
# 5  North Indian Restaurant  0.00
# 6              Observatory  0.00
# 7              Opera House  0.00
# 8             Optical Shop  0.00
# 9          Organic Grocery  0.00
#
#
# ----Wandsworth----
#            venue  freq
# 0            Pub  0.13
# 1           Park  0.12
# 2           Café  0.11
# 3    Coffee Shop  0.10
# 4    Pizza Place  0.05
# 5         Bakery  0.04
# 6    Supermarket  0.04
# 7  Grocery Store  0.03
# 8   Burger Joint  0.02
# 9    Yoga Studio  0.02

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# 10 common venues df

num_top_venues = 10
indicators = ['st', 'nd', 'rd']
# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = lon_grouped['Neighborhood']
for ind in np.arange(lon_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(lon_grouped.iloc[ind, :], num_top_venues)
neighborhoods_venues_sorted
# Out:
#               Neighborhood  ...  10th Most Common Venue
# 0     Barking and Dagenham  ...  Furniture / Home Store
# 1                   Barnet  ...       Fish & Chips Shop
# 2                    Brent  ...             Pizza Place
# 3                  Croydon  ...                Platform
# 4                   Ealing  ...      Persian Restaurant
# 5                  Enfield  ...       Indian Restaurant
# 6                Greenwich  ...          Farmers Market
# 7                  Hackney  ...                Beer Bar
# 8   Hammersmith and Fulham  ...        Toy / Game Store
# 9                 Haringey  ...                     Bar
# 10              Hillingdon  ...      Italian Restaurant
# 11               Islington  ...                     Bar
# 12                 Lambeth  ...   Street Food Gathering
# 13                Lewisham  ...              Restaurant
# 14                  Merton  ...    Gym / Fitness Center
# 15                  Newham  ...  Furniture / Home Store
# 16               Redbridge  ...                  Bakery
# 17               Southwark  ...                   Plaza
# 18          Waltham Forest  ...             Fish Market
# 19              Wandsworth  ...       French Restaurant
#
# [20 rows x 11 columns]

# %% [markdown]
# #### Clustering Neighborhood

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.4.1)

# %%
pip install KMeans
# Out:
# Collecting KMeans
#   Downloading https://files.pythonhosted.org/packages/d1/7e/87d12a99d7ccfd2c85b19899012177e1718c2d6c0148fad421523160e84b/kmeans-1.0.2.tar.gz
# Building wheels for collected packages: KMeans
#   Building wheel for KMeans (setup.py) ... done
#   Created wheel for KMeans: filename=kmeans-1.0.2-cp37-cp37m-linux_x86_64.whl size=11759 sha256=697c602ae9c2ed798a52b9906d51a4e18fe9f9123126360380bada3e4a590c9f
#   Stored in directory: /root/.cache/pip/wheels/10/05/77/2735fd2f7a0b4d86cb7a83be2a56807cf706d5d27f742c6482
# Successfully built KMeans
# Installing collected packages: KMeans
# Successfully installed KMeans-1.0.2

# %%
from sklearn.cluster import KMeans

# %%
# Clustering African Borough

kclusters = 5

lon_grouped_clustering = lon_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(lon_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 
# to change use .astype()
# Out:
# array([2, 0, 4, 4, 0, 4, 0, 0, 0, 0], dtype=int32)

# %% [markdown]
# ### cluster dataframe with 10 common venues

# %%
# add clustering labels

neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

lon_merged = lon_com2

# merge lon_grouped with lon_com2 to add latitude/longitude for each neighborhood
lon_merged = lon_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Borough')

lon_merged.head() # check the last columns!
# Out:
#      Borough  African  ...  9th Most Common Venue  10th Most Common Venue
# 1  Southwark    47413  ...           Cocktail Bar                   Plaza
# 4     Newham    37811  ...                   Park  Furniture / Home Store
# 0    Lambeth    35187  ...                   Park   Street Food Gathering
# 8  Greenwich    35164  ...     Turkish Restaurant          Farmers Market
# 2   Lewisham    32025  ...      Fish & Chips Shop              Restaurant
#
# [5 rows x 15 columns]

# %%
lon_merged.drop(columns=['African'], inplace = True)
lon_merged.head()
# Out:
#      Borough   Latitude  ...  9th Most Common Venue  10th Most Common Venue
# 1  Southwark  51.502922  ...           Cocktail Bar                   Plaza
# 4     Newham  51.530000  ...                   Park  Furniture / Home Store
# 0    Lambeth  51.501301  ...                   Park   Street Food Gathering
# 8  Greenwich  51.482084  ...     Turkish Restaurant          Farmers Market
# 2   Lewisham  51.462432  ...      Fish & Chips Shop              Restaurant
#
# [5 rows x 14 columns]

# %% [markdown]
# ### Visualizing the result

# %%
lon_merged=lon_merged.dropna()

# %%
from matplotlib import cm
import matplotlib.colors as colors

# %%
# ploting cluster in a map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(lon_merged['Latitude'], lon_merged['Longitude'], lon_merged['Borough'], lon_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_1fb6426c135e4361ac16e877423a2ff2%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1fb6426c135e4361ac16e877423a2ff2%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_1fb6426c135e4361ac16e877423a2ff2%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_1fb6426c135e4361ac16e877423a2ff2%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B51.5073219%2C%20-0.1276474%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_422a3f3325d647fe9e884e420da86eee%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%2 ...

# %%
lon_merged['Cluster Labels'].value_counts()
# Out:
# 0    10
# 4     6
# 3     2
# 2     1
# 1     1
# Name: Cluster Labels, dtype: int64

# %% [markdown]
# ##### Analyzing Clusters

# %%
# cluster 1
 
lon_merged.loc[lon_merged['Cluster Labels'] == 0, lon_merged.columns[[1] + list(range(5, lon_merged.shape[1]))]]
# Out:
#      Latitude  ... 10th Most Common Venue
# 8   51.482084  ...         Farmers Market
# 2   51.462432  ...             Restaurant
# 6   51.543240  ...               Beer Bar
# 9   51.587930  ...                    Bar
# 14  51.653090  ...      Fish & Chips Shop
# 12  51.512655  ...     Persian Restaurant
# 13  51.457027  ...      French Restaurant
# 15  51.538429  ...                    Bar
# 17  51.492038  ...       Toy / Game Store
# 18  51.410870  ...   Gym / Fitness Center
#
# [10 rows x 10 columns]

# %%
# cluster 2
lon_merged.loc[lon_merged['Cluster Labels'] == 1, lon_merged.columns[[1] + list(range(5, lon_merged.shape[1]))]]
# Out:
#      Latitude  ... 10th Most Common Venue
# 10  51.198159  ...            Fish Market
#
# [1 rows x 10 columns]

# %%
# cluster 3
lon_merged.loc[lon_merged['Cluster Labels'] == 2, lon_merged.columns[[1] + list(range(5, lon_merged.shape[1]))]]
# Out:
#      Latitude  ...  10th Most Common Venue
# 11  51.554117  ...  Furniture / Home Store
#
# [1 rows x 10 columns]

# %%
# cluster 4
lon_merged.loc[lon_merged['Cluster Labels'] == 3, lon_merged.columns[[1] + list(range(5, lon_merged.shape[1]))]]
# Out:
#     Latitude 2nd Most Common Venue  ... 9th Most Common Venue 10th Most Common Venue
# 1  51.502922                 Hotel  ...          Cocktail Bar                  Plaza
# 0  51.501301             Bookstore  ...                  Park  Street Food Gathering
#
# [2 rows x 10 columns]

# %%
# cluster 5
lon_merged.loc[lon_merged['Cluster Labels'] == 4, lon_merged.columns[[1] + list(range(5, lon_merged.shape[1]))]]
# Out:
#      Latitude  ...  10th Most Common Venue
# 4   51.530000  ...  Furniture / Home Store
# 3   51.371305  ...                Platform
# 7   51.652085  ...       Indian Restaurant
# 5   52.018488  ...             Pizza Place
# 16  51.576320  ...                  Bakery
# 19  51.542519  ...      Italian Restaurant
#
# [6 rows x 10 columns]

# %% [markdown]
# ### Result and conclusion
#
# The following are the highlights of the 5 clusters above:
#
# Southwark is the borough with the highest African population, and it has more coffee shops, hotels, theaters, and pub, with no African brand attached to them. Italian, Turkish, and Indian are common resturants these Boroughs with high African population.
#
# Pubs and coffeeshops are common venues in the south east London.
#
# Cluster 1 and 5 are clusters in which African restaurants, pubs, coffee shops and café to be establish.
